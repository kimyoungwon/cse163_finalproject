# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('FF_allwaves_2019.csv')
# Out:
# /Users/CindyChiu/anaconda/envs/cse163/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (12265,12269,12272,12805,12807,12809,12811,12813,12817,12822,12827,12832,12837,12853,12855,12857,12859,12865,12870,12891,12892,12901,12903,12905,12913,12939,12940,12949,12961,12987,12988,12997,13035,13036,13045,13083,13084,13131,13132,13284,13286,13288,13290,13292,13295,13296,13303,13305,13307,13309,13311,13314,13315,13322,13324,13326,13328,13333,13334,13341,13343,13345,13347,13352,13353,13371,13372,13390,13391,13409,13410,13481,13483,13485,13487,13489,13493,13498,13503,13519,13520,13529,13531,13533,13535,13537,13541,13546,13567,13568,13577,13579,13589,13594,13615,13616,13637,13642,13663,13664,13673,13711,13712,13721,13759,13760,13781,13961,13963,13965,13967,13969,13971,13973,13975,13977,13979,13982,13983,13990,13992,13994,13996,13998,14001,14002,14009,14011,14013,14015,14020,14021,14028,14030,14032,14039,14040,14058,14059,14077,14078) have mixed types. Speci
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  idnum  cf1intmon  cf1intyr  cf1lenhr  cf1lenmin  cf1twoc  \
# 0           1      1          6      1998         1          8        1
# 1           2      2         -9        -9        -9         -9       -9
# 2           3      3          6      1999        -3         30        0
# 3           4      4          5      2000         0         40        0
# 4           5      5         -9        -9        -9         -9       -9
#
#    cf1fint  cf1natsm    f1natwt  ...  h6natwtx_rep1  h6natwtx_rep2  \
# 0        1         1   6.986454  ...            NaN            NaN
# 1        0        -9        NaN  ...            NaN            NaN
# 2        1         1  17.360596  ...            NaN            NaN
# 3        1         1  45.451256  ...            0.0      81.738563
# 4        0        -9        NaN  ...            NaN            NaN
#
#    h6natwtx_rep3  h6natwtx_rep4  h6natwtx_rep5  h6natwtx_rep6  h6natwtx_rep7  \
# ...

# %%
data.shape
# Out:
# (4898, 16994)

# %%
data.columns
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.columns
# Out:
# Index(['idnum', 'cf1intmon', 'cf1intyr', 'cf1lenhr', 'cf1lenmin', 'cf1twoc',
#        'cf1fint', 'cf1natsm', 'f1natwt', 'cf1natsmx',
#        ...
#        'h6natwtx_rep1', 'h6natwtx_rep2', 'h6natwtx_rep3', 'h6natwtx_rep4',
#        'h6natwtx_rep5', 'h6natwtx_rep6', 'h6natwtx_rep7', 'h6natwtx_rep8',
#        'h6natwtx_rep9', 'h6natwtx_rep10'],
#       dtype='object', length=16993)

# %%
data[['m5k2a','m5k2b','m5k2c','m5k2d', 'ch5ppvtraw']]
# Out:
#       m5k2a  m5k2b  m5k2c  m5k2d  ch5ppvtraw
# 0        -6     -6     -6     -6         122
# 1        -6     -6     -6     -6          98
# 2        -9     -9     -9     -9          -9
# 3        -6     -6     -6     -6          92
# 4        -6     -6     -6     -6         102
# 5        -6     -6     -6     -6         124
# 6        -9     -9     -9     -9          -9
# 7        -6     -6     -6     -6          79
# 8        -6     -6     -6     -6         146
# 9        -6     -6     -6     -6          94
# 10       -6     -6     -6     -6          97
# 11       -6     -6     -6     -6          98
# 12       -6     -6     -6     -6         149
# 13       -6     -6     -6     -6         140
# 14       -6     -6     -6     -6         122
# 15       -9     -9     -9     -9          -9
# 16       -9     -9     -9     -9          -9
# 17       -6     -6     -6     -6          96
# 18       -6     -6     -6     -6         114
# 19       -9     -9     -9     -9          -9
# ...

# %%
m9_agg = data[['m5k2a','m5k2b','m5k2c','m5k2d','ch5ppvtraw']]
m9_agg = m9_agg.rename(columns={"m5k2a": "hard", "m5k2b": "trapped", "m5k2c":"work", "m5k2d": "tired",'ch5ppvtraw':'ppvt_raw'})
# filter missing/not in wave
m9_agg = m9_agg[(m9_agg['work']!=-6)&(m9_agg['work']!=-9)&(m9_agg['work']!=-3)]
col_list = m9_agg.columns

# %%
# summing up aggravation
col_list = ['hard','trapped','work','tired']
m9_agg['aggravation'] = m9_agg[col_list].sum(axis=1)
# standardizing aggravation per person
#m9_agg['std'] = m9_agg.std(axis= 1)
#m9_agg['mean'] = m9_agg[col_list].mean(axis=1)
m9_agg
# Out:
#       hard  trapped  work  tired  ppvt_raw  aggravation
# 139      3        4     4      4     130.0           15
# 235      2        4     4      2     129.0           12
# 252      1        4     4      2     109.0           11
# 258      4        4     4      4     104.0           16
# 436      1        1     2      1      88.0            5
# 465      1        4     4      2      94.0           11
# 489      4        3     3      3     105.0           13
# 518      2        4     4      2     115.0           12
# 548      3        4     4      4     101.0           15
# 693      4        4     4      4     121.0           16
# 697      4        4     4      4     102.0           16
# 738      2        4     4      2     116.0           12
# 764      1        4     4      4      84.0           13
# 780      4        4     4      4       NaN           16
# 784      2        3     3      4      92.0           12
# 923      2        4     2      4      88.0           12
# ...

# %%
# fill NaN for ppvt not in wave
m9_agg.loc[m9_agg['ppvt_raw'] == -9,'ppvt_raw'] = np.nan

# %%
sns.regplot('aggravation', 'ppvt_raw', data = m9_agg).set_title('Mother Aggravation vs PPVT')
# Out:
# Text(0.5, 1.0, 'Mother Aggravation vs PPVT')

# %%
results = smf.ols('ppvt_raw ~ hard + trapped + work + tired', data=m9_agg).fit()
results.summary()

# %%
results_agg = smf.ols('ppvt_raw ~ aggravation', data=m9_agg).fit()
results_agg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               ppvt_raw   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     4.120
# Date:                Tue, 04 Jun 2019   Prob (F-statistic):             0.0451
# Time:                        14:07:42   Log-Likelihood:                -453.31
# No. Observations:                 100   AIC:                             910.6
# Df Residuals:                      98   BIC:                             915.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      88.8749     10.226      8.691      0.000      68.582     109.167
# ...

# %%
# Machine Learning part
from sklearn.model_selection import train_test_split 
m9_train, m9_test = train_test_split(m9_agg, test_size = 0.2, random_state=0)

# %%
lm_agg = smf.ols('ppvt_raw ~ aggravation', data=m9_train).fit()
lm_agg.summary()
# filter out nan values
x = m9_train['ppvt_raw'].fillna(0).values
x = x[x!=0]
#lm_agg.predict()

# %%
prediction = lm_agg.predict(exog=dict(aggravation=x)).values

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(prediction,x)
# Out:
# 37084.46770173906

# %%
#sns.regplot(m9_train['aggravation'], prediction).set_title('Mother Aggravation vs PPVT')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-4e704a98dd2e> in <module>
#       1 filtered = m9_train['ppvt_raw'].fillna(0)
# ----> 2 filtered.loc[filtered['ppvt_raw']!=0,'aggravtion']
#       3 #sns.regplot(m9_train['aggravation'], prediction).set_title('Mother Aggravation vs PPVT')
#
# ~/anaconda/envs/cse163/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/anaconda/envs/cse163/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# ...

# %%
x_train = m9_train['aggravation'].values.reshape(-1, 1)
y_train = m9_train['ppvt_raw'].values.reshape(-1, 1)
#x_train = m9_train['aggravation'].reshape(-1, 1)
#y_train = m9_train['ppvt_raw'].reshape(-1, 1)
ml_agg = LinearRegression()
ml_agg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-b634b52c568c> in <module>
#       4 #y_train = m9_train['ppvt_raw'].reshape(-1, 1)
#       5 ml_agg = LinearRegression()
# ----> 6 ml_agg.fit(x_train,y_train)
#
# ~/anaconda/envs/cse163/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
y_train.shape
x_train.shape
# Out:
# (88,)
